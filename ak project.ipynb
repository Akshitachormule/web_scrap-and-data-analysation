# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # import csv file

# %%
df = pd.read_csv('all timebest movie - IMDb.csv', engine='python')

# %%
df
# Out:
#      Unnamed: 0                           title  year  rating metascore  \
# 0             0                 Soorarai Pottru  2020     8.6        na
# 1             1                        Gol Maal  1979     8.6        na
# 2             2                    Black Friday  2004     8.5        76
# 3             3                    Vada Chennai  2018     8.4        na
# 4             4                          Dangal  2016     8.4        na
# ..          ...                             ...   ...     ...       ...
# 345         345                     Housefull 2  2012     5.3        na
# 346         346          A Good Day to Die Hard  2013     5.3        28
# 347         347                          Race 2  2013     5.3        na
# 348         348  Gunjan Saxena: The Kargil Girl  2020     5.3        na
# 349         349                        The Guru  2002     5.3        47
#
#     certificate    votes  runtime                                 gener  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   350 non-null    int64
#  1   title        350 non-null    object
#  2   year         350 non-null    object
#  3   rating       350 non-null    float64
#  4   metascore    350 non-null    object
#  5   certificate  350 non-null    object
#  6   votes        350 non-null    object
#  7   runtime      350 non-null    object
#  8   gener        350 non-null    object
#  9   director     350 non-null    object
#  10  star1        350 non-null    object
#  11  star2        350 non-null    object
#  12  star3        350 non-null    object
#  13  star4        350 non-null    object
#  14  gross        350 non-null    object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 41.1+ KB

# %% [markdown]
# # RATINGS

# %%
df1=df.sort_values('rating',ascending=[False]).head(10)
df1.index= np.arange(1,11)
df1
# Out:
#     Unnamed: 0               title  year  rating metascore certificate  \
# 1            0     Soorarai Pottru  2020     8.6        na           U
# 2            1            Gol Maal  1979     8.6        na           U
# 3            2        Black Friday  2004     8.5        76    (Banned)
# 4            3        Vada Chennai  2018     8.4        na          18
# 5            4              Dangal  2016     8.4        na           U
# 6            5            3 Idiots  2009     8.4        67          UA
# 7            6    Taare Zameen Par  2007     8.4        na           U
# 8            7  Jaane Bhi Do Yaaro  1983     8.4        na           U
# 9           10       Chupke Chupke  1975     8.3        na           U
# 10          11               Anand  1971     8.3        na           U
#
#       votes  runtime                                 gener  \
# 1    58,742  153 min                     Drama
# 2    18,169  144 min           Comedy, Romance
# ...

# %%
df1=df.sort_values('rating',ascending=[False]).tail(10)
df1.index= np.arange(1,11)
df1
# Out:
#     Unnamed: 0                           title  year  rating metascore  \
# 1          340             Jab Harry Met Sejal  2017     5.3        na
# 2          341      The Other Side of the Door  2016     5.3        41
# 3          342                            Kick  2014     5.3        na
# 4          343             Student of the Year  2012     5.3        na
# 5          344                        Geostorm  2017     5.3        21
# 6          345                     Housefull 2  2012     5.3        na
# 7          346          A Good Day to Die Hard  2013     5.3        28
# 8          347                          Race 2  2013     5.3        na
# 9          348  Gunjan Saxena: The Kargil Girl  2020     5.3        na
# 10         349                        The Guru  2002     5.3        47
#
#    certificate    votes  runtime                                 gener  \
# 1           UA   18,924  143 min    Comedy, Drama, Romance
# ...

# %%
ratings=df.groupby(["title",'votes'])["rating"].sum()

# %%
average_rating=df['rating'].mean()
average_rating
# Out:
# 7.247428571428567

# %%
ratings=ratings.reset_index()
ratings
# Out:
#                         title    votes  rating
# 0                    2 States   23,714     6.9
# 1                         2.0   21,450     6.2
# 2                        2012  357,101     5.8
# 3                    3 Idiots  351,003     8.4
# 4      A Good Day to Die Hard  199,551     5.3
# ..                        ...      ...     ...
# 345   Yeh Jawaani Hai Deewani   38,966     7.1
# 346                  Yes Boss   12,570     6.8
# 347                      Zero   23,974     5.4
# 348  Zindagi Na Milegi Dobara   68,973     8.2
# 349    Zombieland: Double Tap  145,242     6.7
#
# [350 rows x 3 columns]

# %%
ratings["rating"].max()
# Out:
# 8.6

# %%
ratings["rating"].min()
# Out:
# 5.3

# %% [markdown]
# ### list of head 10 movie having rating above the avg rating

# %%
ratings[ratings["rating"]>=average_rating].head(10)
# Out:
#                  title    votes  rating
# 3             3 Idiots  351,003     8.4
# 5   A Passage to India   17,269     7.3
# 6          A Wednesday   74,407     8.1
# 8                Aamir   10,743     7.7
# 9              Aankhen   12,442     7.4
# 13             Airlift   53,244     8.0
# 15               Anand   31,258     8.3
# 16     Andaz Apna Apna   49,719     8.2
# 17           Andhadhun   74,926     8.2
# 18      Angrezi Medium   11,122     7.3

# %% [markdown]
# ### list of head 10 movie having rating below the avg rating

# %%
ratings[ratings["rating"]<average_rating].head(10)
# Out:
#                           title    votes  rating
# 0                      2 States   23,714     6.9
# 1                           2.0   21,450     6.2
# 2                          2012  357,101     5.8
# 4        A Good Day to Die Hard  199,551     5.3
# 7                      AK vs AK   11,802     7.0
# 10                   Aashiqui 2   26,950     7.0
# 11           Ae Dil Hai Mushkil   21,349     5.8
# 12                    Agneepath   22,592     6.9
# 14   Ajab Prem Ki Ghazab Kahani   12,894     6.4
# 20  Around the World in 80 Days   85,918     5.9

# %%
plt.figure(figsize=(15,5))
df["rating"].value_counts().plot(kind="bar") # pandas barplot
plt.ylabel("count")
plt.xlabel("rating")
plt.show()

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.kdeplot(df['rating'])
g.set_title("rating of all movies", weight = "bold")
# Out:
# Text(0.5, 1.0, 'rating of all movies')

# %% [markdown]
# # META SCORE

# %%
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=df['title'][:7],y=df['metascore'][:7], palette = 'husl')
g.set_title("Metascore of top rated movies", weight = "bold")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-af314d96ba04> in <module>
#       1 fig,axs=plt.subplots(figsize=(15,5))
# ----> 2 g=sns.barplot(x=df['title'][:7],y=df['metascore'][:7], palette = 'husl')
#       3 g.set_title("Metascore of top rated movies", weight = "bold")
#       4 plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3167 ):
#    3168
# ...

# %%
ax = sns.distplot(df['metascore']) # histogram distribution

# %% [markdown]
# # ***Runtime***

# %% [markdown]
# ### GETTING TOP 5  movie HAVING LONGEST RUNTIME & SMALLEST RUNTIME

# %%
df1=df.sort_values('runtime',ascending=[False]).head(5)
df1.index= np.arange(1,6)
df1

# %%
df1=df.sort_values('runtime',ascending=[False]).tail(5)
df1.index= np.arange(1,6)
df1

# %% [markdown]
# ### AVERAGE RUNTIME

# %%
runtime=df.groupby(["title"])["runtime"].sum()

# %%
average_runtime=df['runtime'].mean()
average_runtime

# %%
runtime=runtime.reset_index()
runtime

# %% [markdown]
# #### movie with maximum runtime

# %%
runtime["runtime"].max()

# %%
runtime[runtime["runtime"]==353]

# %% [markdown]
# #### movie with minimum runtime

# %%
runtime["runtime"].min()

# %%
runtime[runtime["runtime"]==81]

# %% [markdown]
# ### list of head 10 movie having runtime above the avg runtime

# %%
runtime[runtime["runtime"]>average_runtime].head(10)

# %% [markdown]
# ### ***list of head 10 anime having runtime below the avg runtime***

# %%
runtime[runtime["runtime"]<average_runtime].head(10)

# %%
plt.figure(figsize=(7,7))
plt.hist(df["runtime"],bins=10)
plt.title("runtime frequency distribution")
plt.ylabel("frequency")
plt.xlabel("runtime")
plt.show

# %% [markdown]
# # Finding correlation

# %%
df.corr()

# %%
numerical_attributes = ['rating', 'runtime','metascore']
df[numerical_attributes].hist(figsize = (15, 6), color = 'blue', edgecolor = 'red', layout = (2, 2));

# %% [markdown]
# # ***CERTIFICATE***

# %% [markdown]
# ### analyzing the movie content is sutiable for age group

# %%
series = df.certificate
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());

# %%
df['certificate']=df['certificate'].fillna('Not Rated')

certificates=df[df['certificate']!='Not Rated']['certificate']
fig,axs=plt.subplots(figsize=(20,5))
g=sns.countplot(certificates)
g.set_title("Count of Certificates provided", weight = "bold")
plt.show()

# %%
catdata=['certificate']
# pandas plot pie plot 
for i in catdata:
    plt.figure(figsize=(60,90))
    df[i].value_counts().plot.pie(autopct="%1.2f%%",fontsize=25)
    plt.title("certificate", fontsize=20)
    plt.show()

# %% [markdown]
# # Actors

# %% [markdown]
# #### Actor 1

# %%
series = df.star1
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());

# %% [markdown]
# #### Actor2

# %%
series = df.star2
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());

# %% [markdown]
# #### Actor 3

# %%
series = df.star3
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode())

# %% [markdown]
# #### Actor 4

# %%
series = df.star4
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode())

# %%
stars=['star4','star3','star2','star4']
fig,axs=plt.subplots(4,1,figsize=(20,20))
ax=0
for x in stars:
    axs[ax].bar(df[x].value_counts()[:10].index,df[x].value_counts()[:10])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %%
stars=['star1','star2','star3','star4']
fig,axs=plt.subplots(4,1,figsize=(20,10))
ax=0
for x in stars:
    s=df.groupby([x]).sum().reset_index()
    d=s.sort_values(['rating'],ascending=False)[:10]
    axs[ax].bar(d[x],d['rating'])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %% [markdown]
# # Directors

# %%
fig,axs=plt.subplots(figsize=(15,5))
g=sns.barplot(x=df['director'].value_counts()[:10].index,y=df['gross'].value_counts()[:10])
g.set_title("Directors", weight = "bold")
g.set_xlabel("Mostly Occurred", weight = "bold")
plt.show()

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.lineplot(x=df['director'].value_counts()[:10].index,y=df['year'].value_counts()[:10])
g.set_title("Mostly Occurred Directors", weight = "bold")
g.set_xlabel("director", weight = "bold")
plt.show()

# %% [markdown]
# # MOVIE GENRES

# %%
series = df.gener
# counting the frequency of each element
freq = series.value_counts()
print("Printing the frequency")
display(freq)
  
# printing the most frequent element
print("Printing the most frequent element of series")
display(series.mode());

# %%
plt.figure(figsize=(20,20))
sns.countplot(data=df,y="gener")
plt.show()

# %%
plt.figure(figsize=(25,25))
sns.barplot(x='rating',y="gener",data=df)
plt.show()

# %%
from collections import Counter
genre=[]
for x in df['gener']:
    for y in x.split(','):
        genre.append(y.strip().lower())

count=Counter(genre)
count=count.most_common()[:10]
x,y=map(list,zip(*count))

fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(y,x)
g.set_ylabel("Genres", weight = "bold")
g.set_title("Top Ten Genres", weight = "bold")
plt.show()

# %% [markdown]
# # maximum movies released in-

# %%
fig,axs=plt.subplots(figsize=(20,5))
g=sns.barplot(x=df['year'].value_counts()[:10].index,y=df['year'].value_counts()[:10])
g.set_title("Maximum movies released in-", weight = "bold")
g.set_xlabel("year")
plt.show()

# %% [markdown]
# # Appearances of Stars in Top voted movies

# %%
stars=['star1','star2','star3','star4']
fig,axs=plt.subplots(4,1,figsize=(20,15))
ax=0
for x in stars:
    s=df.groupby([x]).sum().reset_index()
    d=df.sort_values(['votes'],ascending=False)[:9]
    axs[ax].bar(d[x],d['votes'])
    axs[ax].set_title(x)
    axs[ax].set_ylabel("Appearances", weight = "bold")
    ax+=1
    plt.tight_layout()

# %% [markdown]
# # Conlusion

# %% [markdown]
# Here we have analyzed the data of top rated indian movies and by analyzing the data we have concluded the regarding points.<br>
# 1. we have seen top 10 high rated as well as low rated movies.
# 2. we have seen metascores of top rated movies.
# 3. we have seen which movie have the longest and smallest runtime.
# 4. we have observe the correlations.
# 5. we have seen the certificate provided to the movie.
# 6. appearence of the actors in the top rated movies and also directors.
# 7. we have seen gener of the movie which are repeatedly created.
# From above points we have concluded that it is easy to understand the data by visualization which are based on above points.

# %%
import pandas_profiling as pp

# %%
report = pp.ProfileReport(df)

report.to_file("report.html")

report
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.11.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-04-28 18:06:18.480348&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
